# %% [markdown]
# # Consolidate GAINS emissions
#
# - Add biomass burning CH4 to GAINS inventories
# - Add fossil/AFOLU CO2 split from AR6 database
# - reorganise emissions files to format that can be used in harmonization

# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# %%
gains_df = pd.read_csv('../data/ch4_gains-ipcc_scenarios_4feb2023_database_corrected.csv')

# %%
gains_df
# Out:
#        sc                 model            scenario            MPscen  \
# 0     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE
# 1     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech
# 2     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore
# 3     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc
# 4     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior
# ...   ...                   ...                 ...               ...
# 1690  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NH3
# 1691  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NOx
# 1692  833  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC
# 1693  833  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur
# 1694  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC
#
#            y1990       y1991       y1992       y1993       y1994       y1995  \
# 0     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 1     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 2     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 3     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 4     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# ...          ...         ...         ...         ...         ...         ...
# 1690         NaN         NaN         NaN         NaN         NaN         NaN
# 1691         NaN         NaN         NaN         NaN         NaN         NaN
# 1692         NaN         NaN         NaN         NaN         NaN         NaN
# 1693         NaN         NaN         NaN         NaN         NaN         NaN
# 1694         NaN         NaN         NaN         NaN         NaN         NaN
#
#       ...       y2040    y2045       y2050    y2055       y2060       y2070  \
# 0     ...  425.334009      NaN  460.999873      NaN  484.178829  492.704624
# 1     ...  254.601969      NaN  253.791865      NaN  270.464730  280.477734
# 2     ...  253.300442      NaN  252.454499      NaN  269.096264  279.093029
# 3     ...  239.794999      NaN  232.214116      NaN  248.994325  257.725260
# 4     ...  205.847732      NaN  198.896022      NaN  215.531464  224.808898
# ...   ...         ...      ...         ...      ...         ...         ...
# 1690  ...    1.146800   1.0248    0.911200   0.8971    0.869100    0.812200
# 1691  ...   95.455600  83.2434   70.855000  71.7009   71.742700   69.564700
# 1692  ...   23.359100  21.8933   20.622400  20.0945   19.602000   18.785800
# 1693  ...   58.641600  48.7633   38.572900  38.9534   38.766900   37.080500
# 1694  ...  104.869500  94.0495   83.533800  80.9232   78.413900   73.696000
#
#            y2080       y2090       y2100  rank
# 0     493.081016  477.740000  458.001268     1
# 1     285.729495  287.242139  285.347242     2
# 2     284.342611  285.865296  283.997366     3
# 3     264.433003  268.243567  269.414432     4
# 4     232.398358  237.492262  240.051394     5
# ...          ...         ...         ...   ...
# 1690    0.769100    0.725700    0.689300    15
# 1691   66.244000   62.245600   56.906300    16
# 1692   18.131000   17.905200   18.027400    17
# 1693   33.979500   29.761600   25.015200    19
# 1694   70.033200   67.829600   67.186400    20
#
# [1695 rows x 48 columns]

# %%
gains_df["MPscen"].unique()
# Out:
# array(['Baseline_CLE', 'MFR_tech', 'MFR_explore', 'MFR_struc',
#        'MFR_behavior', 'MFR_develop', 'Emissions|BC', 'Emissions|CO',
#        'Emissions|CO2', 'Emissions|N2O', 'Emissions|NH3', 'Emissions|NOx',
#        'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC'], dtype=object)

# %%
gains_df.drop(columns=["sc", "rank"], inplace=True)  # adds nothing

# %%
gains_df.drop(
    gains_df.loc[
        gains_df['MPscen'].isin(
            (
#                 'Emissions|PFC',
#                 'Emissions|HFC'
                'Emissions|CO2',
            ),
        )
    ].index,
inplace=True)  # no aggregates please

# %%
gains_df
# Out:
#                      model            scenario            MPscen       y1990  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE  307.731045
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech  307.731045
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore  307.731045
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc  307.731045
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior  307.731045
# ...                    ...                 ...               ...         ...
# 1690  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NH3         NaN
# 1691  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NOx         NaN
# 1692  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC         NaN
# 1693  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur         NaN
# 1694  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC         NaN
#
#            y1991       y1992       y1993       y1994       y1995      y1996  \
# 0     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 1     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 2     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 3     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 4     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# ...          ...         ...         ...         ...         ...        ...
# 1690         NaN         NaN         NaN         NaN         NaN        NaN
# 1691         NaN         NaN         NaN         NaN         NaN        NaN
# 1692         NaN         NaN         NaN         NaN         NaN        NaN
# 1693         NaN         NaN         NaN         NaN         NaN        NaN
# 1694         NaN         NaN         NaN         NaN         NaN        NaN
#
#       ...     y2035       y2040    y2045       y2050    y2055       y2060  \
# 0     ...       NaN  425.334009      NaN  460.999873      NaN  484.178829
# 1     ...       NaN  254.601969      NaN  253.791865      NaN  270.464730
# 2     ...       NaN  253.300442      NaN  252.454499      NaN  269.096264
# 3     ...       NaN  239.794999      NaN  232.214116      NaN  248.994325
# 4     ...       NaN  205.847732      NaN  198.896022      NaN  215.531464
# ...   ...       ...         ...      ...         ...      ...         ...
# 1690  ...    1.2779    1.146800   1.0248    0.911200   0.8971    0.869100
# 1691  ...  106.8348   95.455600  83.2434   70.855000  71.7009   71.742700
# 1692  ...   24.9680   23.359100  21.8933   20.622400  20.0945   19.602000
# 1693  ...   68.7234   58.641600  48.7633   38.572900  38.9534   38.766900
# 1694  ...  115.5794  104.869500  94.0495   83.533800  80.9232   78.413900
#
#            y2070       y2080       y2090       y2100
# 0     492.704624  493.081016  477.740000  458.001268
# 1     280.477734  285.729495  287.242139  285.347242
# 2     279.093029  284.342611  285.865296  283.997366
# 3     257.725260  264.433003  268.243567  269.414432
# 4     224.808898  232.398358  237.492262  240.051394
# ...          ...         ...         ...         ...
# 1690    0.812200    0.769100    0.725700    0.689300
# 1691   69.564700   66.244000   62.245600   56.906300
# 1692   18.785800   18.131000   17.905200   18.027400
# 1693   37.080500   33.979500   29.761600   25.015200
# 1694   73.696000   70.033200   67.829600   67.186400
#
# [1582 rows x 46 columns]

# %%
gains_df.insert(loc=3, column="variable", value="Emissions|CH4")

# %%
gains_df
# Out:
#                      model            scenario            MPscen  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior
# ...                    ...                 ...               ...
# 1690  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NH3
# 1691  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NOx
# 1692  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC
# 1693  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur
# 1694  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC
#
#            variable       y1990       y1991       y1992       y1993  \
# 0     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 1     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 2     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 3     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 4     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# ...             ...         ...         ...         ...         ...
# 1690  Emissions|CH4         NaN         NaN         NaN         NaN
# 1691  Emissions|CH4         NaN         NaN         NaN         NaN
# 1692  Emissions|CH4         NaN         NaN         NaN         NaN
# 1693  Emissions|CH4         NaN         NaN         NaN         NaN
# 1694  Emissions|CH4         NaN         NaN         NaN         NaN
#
#            y1994       y1995  ...     y2035       y2040    y2045       y2050  \
# 0     296.347795  294.214088  ...       NaN  425.334009      NaN  460.999873
# 1     296.347795  294.214088  ...       NaN  254.601969      NaN  253.791865
# 2     296.347795  294.214088  ...       NaN  253.300442      NaN  252.454499
# 3     296.347795  294.214088  ...       NaN  239.794999      NaN  232.214116
# 4     296.347795  294.214088  ...       NaN  205.847732      NaN  198.896022
# ...          ...         ...  ...       ...         ...      ...         ...
# 1690         NaN         NaN  ...    1.2779    1.146800   1.0248    0.911200
# 1691         NaN         NaN  ...  106.8348   95.455600  83.2434   70.855000
# 1692         NaN         NaN  ...   24.9680   23.359100  21.8933   20.622400
# 1693         NaN         NaN  ...   68.7234   58.641600  48.7633   38.572900
# 1694         NaN         NaN  ...  115.5794  104.869500  94.0495   83.533800
#
#         y2055       y2060       y2070       y2080       y2090       y2100
# 0         NaN  484.178829  492.704624  493.081016  477.740000  458.001268
# 1         NaN  270.464730  280.477734  285.729495  287.242139  285.347242
# 2         NaN  269.096264  279.093029  284.342611  285.865296  283.997366
# 3         NaN  248.994325  257.725260  264.433003  268.243567  269.414432
# 4         NaN  215.531464  224.808898  232.398358  237.492262  240.051394
# ...       ...         ...         ...         ...         ...         ...
# 1690   0.8971    0.869100    0.812200    0.769100    0.725700    0.689300
# 1691  71.7009   71.742700   69.564700   66.244000   62.245600   56.906300
# 1692  20.0945   19.602000   18.785800   18.131000   17.905200   18.027400
# 1693  38.9534   38.766900   37.080500   33.979500   29.761600   25.015200
# 1694  80.9232   78.413900   73.696000   70.033200   67.829600   67.186400
#
# [1582 rows x 47 columns]

# %%
#lambda x: x['col3'] if x['col1'] < x['col2'] else x['col1'], axis=1

gains_df["variable"] = gains_df.apply(
    lambda x: x["MPscen"] if x["MPscen"].startswith("Emissions") else x["variable"], axis=1
)

# %%
gains_df["MPscen"] = gains_df.apply(
    lambda x: "" if x["MPscen"].startswith("Emissions") else x["MPscen"], axis=1
)

# %%
gains_df.head(16)
# Out:
#                    model        scenario        MPscen          variable  \
# 0   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15  Baseline_CLE     Emissions|CH4
# 1   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15      MFR_tech     Emissions|CH4
# 2   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15   MFR_explore     Emissions|CH4
# 3   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15     MFR_struc     Emissions|CH4
# 4   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15  MFR_behavior     Emissions|CH4
# 5   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15   MFR_develop     Emissions|CH4
# 6   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|BC
# 7   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|CO
# 9   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|N2O
# 10  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|NH3
# 11  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|NOx
# 12  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|OC
# 13  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                Emissions|Sulfur
# 14  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|VOC
# 15  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_50  Baseline_CLE     Emissions|CH4
# 16  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_50      MFR_tech     Emissions|CH4
#
#          y1990       y1991       y1992       y1993       y1994       y1995  \
# 0   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 1   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 2   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 3   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 4   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 5   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 15  307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 16  307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
#
#     ...  y2035         y2040  y2045        y2050  y2055        y2060  \
# 0   ...    NaN    425.334009    NaN   460.999873    NaN   484.178829
# 1   ...    NaN    254.601969    NaN   253.791865    NaN   270.464730
# 2   ...    NaN    253.300442    NaN   252.454499    NaN   269.096264
# 3   ...    NaN    239.794999    NaN   232.214116    NaN   248.994325
# 4   ...    NaN    205.847732    NaN   198.896022    NaN   215.531464
# 5   ...    NaN    200.365945    NaN   194.735280    NaN   210.639939
# 6   ...    NaN      4.808490    NaN     3.956173    NaN     3.243609
# 7   ...    NaN    609.860001    NaN   490.887943    NaN   395.811096
# 9   ...    NaN  10409.713918    NaN  9866.405888    NaN  9429.984825
# 10  ...    NaN     49.116823    NaN    45.356468    NaN    42.760863
# 11  ...    NaN     85.922235    NaN    74.979329    NaN    65.664979
# 12  ...    NaN     22.363409    NaN    18.778280    NaN    15.851079
# 13  ...    NaN     49.151020    NaN    35.643290    NaN    27.835236
# 14  ...    NaN    150.418764    NaN   130.213601    NaN   112.940302
# 15  ...    NaN    410.899477    NaN   434.829935    NaN   446.657258
# 16  ...    NaN    245.026062    NaN   241.384881    NaN   251.317483
#
#           y2070        y2080        y2090        y2100
# 0    492.704624   493.081016   477.740000   458.001268
# 1    280.477734   285.729495   287.242139   285.347242
# 2    279.093029   284.342611   285.865296   283.997366
# 3    257.725260   264.433003   268.243567   269.414432
# 4    224.808898   232.398358   237.492262   240.051394
# 5    219.204814   226.080483   230.344132   231.991915
# 6      2.676115     2.161367     1.756185     1.706583
# 7    325.675492   261.159458   222.211163   201.934730
# 9   8900.429244  8040.052841  7625.449768  7215.610324
# 10    37.994416    34.389574    31.704919    29.309005
# 11    60.315190    56.645282    50.866496    46.828176
# 12    13.209554    10.489218     8.746397     8.180065
# 13    24.163113    21.855455    19.543079    17.618124
# 14    99.868037    85.917658    75.863451    71.968113
# 15   430.617540   412.645537   390.613245   377.810689
# 16   250.477633   246.726793   242.304648   242.516925
#
# [16 rows x 47 columns]

# %%
new_df = pd.DataFrame(columns = gains_df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [model, scenario, MPscen, variable, y1990, y1991, y1992, y1993, y1994, y1995, y1996, y1997, y1998, y1999, y2000, y2001, y2002, y2003, y2004, y2005, y2006, y2007, y2008, y2009, y2010, y2011, y2012, y2013, y2014, y2015, y2016, y2017, y2018, y2019, y2020, y2025, y2030, y2035, y2040, y2045, y2050, y2055, y2060, y2070, y2080, y2090, y2100]
# Index: []
#
# [0 rows x 47 columns]

# %%
# assign new unique index to first new element
idx = gains_df.index.max() + 1
idx
# Out:
# 1695

# %%
for ms, data in tqdm(gains_df.groupby(["model", "scenario"])):
    #print(gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])])
    
    for MPscen in data["MPscen"].unique():
        if MPscen != "":
            for variable in np.delete(data["variable"].unique(), np.where(data["variable"].unique()=='Emissions|CH4')):
                new_df.loc[idx, :] = gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["variable"]==variable)].values
                new_df.loc[idx, 'MPscen'] = MPscen
                #print(gains_df.loc[
                #    (gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["MPscen"]==MPscen)
                #])
                #new_df.loc
                #print(gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["variable"]==variable)])
                idx = idx + 1
# Out:
#   0%|          | 0/113 [00:00<?, ?it/s]

# %%
new_df
# Out:
#                      model            scenario        MPscen  \
# 1695  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1696  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1697  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1698  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1699  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# ...                    ...                 ...           ...
# 7114  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7115  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7116  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7117  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7118  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
#
#               variable y1990 y1991 y1992 y1993 y1994 y1995  ...     y2035  \
# 1695      Emissions|BC   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1696      Emissions|CO   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1697     Emissions|N2O   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1698     Emissions|NH3   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1699     Emissions|NOx   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# ...                ...   ...   ...   ...   ...   ...   ...  ...       ...
# 7114     Emissions|NH3   NaN   NaN   NaN   NaN   NaN   NaN  ...    1.2779
# 7115     Emissions|NOx   NaN   NaN   NaN   NaN   NaN   NaN  ...  106.8348
# 7116      Emissions|OC   NaN   NaN   NaN   NaN   NaN   NaN  ...    24.968
# 7117  Emissions|Sulfur   NaN   NaN   NaN   NaN   NaN   NaN  ...   68.7234
# 7118     Emissions|VOC   NaN   NaN   NaN   NaN   NaN   NaN  ...  115.5794
#
#              y2040    y2045        y2050    y2055        y2060        y2070  \
# 1695       4.80849      NaN     3.956173      NaN     3.243609     2.676115
# 1696    609.860001      NaN   490.887943      NaN   395.811096   325.675492
# 1697  10409.713918      NaN  9866.405888      NaN  9429.984825  8900.429244
# 1698     49.116823      NaN    45.356468      NaN    42.760863    37.994416
# 1699     85.922235      NaN    74.979329      NaN    65.664979     60.31519
# ...            ...      ...          ...      ...          ...          ...
# 7114        1.1468   1.0248       0.9112   0.8971       0.8691       0.8122
# 7115       95.4556  83.2434       70.855  71.7009      71.7427      69.5647
# 7116       23.3591  21.8933      20.6224  20.0945       19.602      18.7858
# 7117       58.6416  48.7633      38.5729  38.9534      38.7669      37.0805
# 7118      104.8695  94.0495      83.5338  80.9232      78.4139       73.696
#
#             y2080        y2090        y2100
# 1695     2.161367     1.756185     1.706583
# 1696   261.159458   222.211163    201.93473
# 1697  8040.052841  7625.449768  7215.610324
# 1698    34.389574    31.704919    29.309005
# 1699    56.645282    50.866496    46.828176
# ...           ...          ...          ...
# 7114       0.7691       0.7257       0.6893
# 7115       66.244      62.2456      56.9063
# 7116       18.131      17.9052      18.0274
# 7117      33.9795      29.7616      25.0152
# 7118      70.0332      67.8296      67.1864
#
# [5424 rows x 47 columns]

# %%
gains_df = pd.concat((gains_df, new_df))

# %%
gains_df["MPscen"].unique()
# Out:
# array(['Baseline_CLE', 'MFR_tech', 'MFR_explore', 'MFR_struc',
#        'MFR_behavior', 'MFR_develop', ''], dtype=object)

# %%
gains_df.drop(gains_df[gains_df.MPscen == ""].index, inplace=True)

# %%
methane_scenarios = gains_df["MPscen"].unique()

# %%
gains_df
# Out:
#                      model            scenario        MPscen  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_tech
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15   MFR_explore
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15     MFR_struc
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  MFR_behavior
# ...                    ...                 ...           ...
# 7114  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7115  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7116  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7117  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7118  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
#
#               variable       y1990       y1991       y1992       y1993  \
# 0        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 1        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 2        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 3        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 4        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# ...                ...         ...         ...         ...         ...
# 7114     Emissions|NH3         NaN         NaN         NaN         NaN
# 7115     Emissions|NOx         NaN         NaN         NaN         NaN
# 7116      Emissions|OC         NaN         NaN         NaN         NaN
# 7117  Emissions|Sulfur         NaN         NaN         NaN         NaN
# 7118     Emissions|VOC         NaN         NaN         NaN         NaN
#
#            y1994       y1995  ...     y2035       y2040    y2045       y2050  \
# 0     296.347795  294.214088  ...       NaN  425.334009      NaN  460.999873
# 1     296.347795  294.214088  ...       NaN  254.601969      NaN  253.791865
# 2     296.347795  294.214088  ...       NaN  253.300442      NaN  252.454499
# 3     296.347795  294.214088  ...       NaN  239.794999      NaN  232.214116
# 4     296.347795  294.214088  ...       NaN  205.847732      NaN  198.896022
# ...          ...         ...  ...       ...         ...      ...         ...
# 7114         NaN         NaN  ...    1.2779      1.1468   1.0248      0.9112
# 7115         NaN         NaN  ...  106.8348     95.4556  83.2434      70.855
# 7116         NaN         NaN  ...    24.968     23.3591  21.8933     20.6224
# 7117         NaN         NaN  ...   68.7234     58.6416  48.7633     38.5729
# 7118         NaN         NaN  ...  115.5794    104.8695  94.0495     83.5338
#
#         y2055       y2060       y2070       y2080       y2090       y2100
# 0         NaN  484.178829  492.704624  493.081016      477.74  458.001268
# 1         NaN   270.46473  280.477734  285.729495  287.242139  285.347242
# 2         NaN  269.096264  279.093029  284.342611  285.865296  283.997366
# 3         NaN  248.994325   257.72526  264.433003  268.243567  269.414432
# 4         NaN  215.531464  224.808898  232.398358  237.492262  240.051394
# ...       ...         ...         ...         ...         ...         ...
# 7114   0.8971      0.8691      0.8122      0.7691      0.7257      0.6893
# 7115  71.7009     71.7427     69.5647      66.244     62.2456     56.9063
# 7116  20.0945      19.602     18.7858      18.131     17.9052     18.0274
# 7117  38.9534     38.7669     37.0805     33.9795     29.7616     25.0152
# 7118  80.9232     78.4139      73.696     70.0332     67.8296     67.1864
#
# [6102 rows x 47 columns]

# %%
gains_df['scen'] = gains_df['scenario'] + '|' + gains_df['MPscen']

# %%
gains_df
# Out:
#                      model            scenario        MPscen  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_tech
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15   MFR_explore
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15     MFR_struc
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  MFR_behavior
# ...                    ...                 ...           ...
# 7114  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7115  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7116  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7117  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 7118  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
#
#               variable       y1990       y1991       y1992       y1993  \
# 0        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 1        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 2        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 3        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 4        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# ...                ...         ...         ...         ...         ...
# 7114     Emissions|NH3         NaN         NaN         NaN         NaN
# 7115     Emissions|NOx         NaN         NaN         NaN         NaN
# 7116      Emissions|OC         NaN         NaN         NaN         NaN
# 7117  Emissions|Sulfur         NaN         NaN         NaN         NaN
# 7118     Emissions|VOC         NaN         NaN         NaN         NaN
#
#            y1994       y1995  ...       y2040    y2045       y2050    y2055  \
# 0     296.347795  294.214088  ...  425.334009      NaN  460.999873      NaN
# 1     296.347795  294.214088  ...  254.601969      NaN  253.791865      NaN
# 2     296.347795  294.214088  ...  253.300442      NaN  252.454499      NaN
# 3     296.347795  294.214088  ...  239.794999      NaN  232.214116      NaN
# 4     296.347795  294.214088  ...  205.847732      NaN  198.896022      NaN
# ...          ...         ...  ...         ...      ...         ...      ...
# 7114         NaN         NaN  ...      1.1468   1.0248      0.9112   0.8971
# 7115         NaN         NaN  ...     95.4556  83.2434      70.855  71.7009
# 7116         NaN         NaN  ...     23.3591  21.8933     20.6224  20.0945
# 7117         NaN         NaN  ...     58.6416  48.7633     38.5729  38.9534
# 7118         NaN         NaN  ...    104.8695  94.0495     83.5338  80.9232
#
#            y2060       y2070       y2080       y2090       y2100  \
# 0     484.178829  492.704624  493.081016      477.74  458.001268
# 1      270.46473  280.477734  285.729495  287.242139  285.347242
# 2     269.096264  279.093029  284.342611  285.865296  283.997366
# 3     248.994325   257.72526  264.433003  268.243567  269.414432
# 4     215.531464  224.808898  232.398358  237.492262  240.051394
# ...          ...         ...         ...         ...         ...
# 7114      0.8691      0.8122      0.7691      0.7257      0.6893
# 7115     71.7427     69.5647      66.244     62.2456     56.9063
# 7116      19.602     18.7858      18.131     17.9052     18.0274
# 7117     38.7669     37.0805     33.9795     29.7616     25.0152
# 7118     78.4139      73.696     70.0332     67.8296     67.1864
#
#                                 scen
# 0        SSP2_int_lc_15|Baseline_CLE
# 1            SSP2_int_lc_15|MFR_tech
# 2         SSP2_int_lc_15|MFR_explore
# 3           SSP2_int_lc_15|MFR_struc
# 4        SSP2_int_lc_15|MFR_behavior
# ...                              ...
# 7114  Transport_NPi_Conv|MFR_develop
# 7115  Transport_NPi_Conv|MFR_develop
# 7116  Transport_NPi_Conv|MFR_develop
# 7117  Transport_NPi_Conv|MFR_develop
# 7118  Transport_NPi_Conv|MFR_develop
#
# [6102 rows x 48 columns]

# %%
gains_df.drop(columns = ['scenario', 'MPscen'], inplace=True)

# %%
gains_df.rename(columns={"scen": "scenario"}, inplace=True)

# %%
years = list(range(1990, 2020)) + list(range(2020, 2060, 5)) + list(range(2060, 2110, 10))
years
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2060,
#  2070,
#  2080,
#  2090,
#  2100]

# %%
gains_df.rename(columns={f'y{year}': year for year in years}, inplace=True)

# %%
gains_df
# Out:
#                      model          variable        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# ...                    ...               ...         ...         ...
# 7114  REMIND-Transport 2.1     Emissions|NH3         NaN         NaN
# 7115  REMIND-Transport 2.1     Emissions|NOx         NaN         NaN
# 7116  REMIND-Transport 2.1      Emissions|OC         NaN         NaN
# 7117  REMIND-Transport 2.1  Emissions|Sulfur         NaN         NaN
# 7118  REMIND-Transport 2.1     Emissions|VOC         NaN         NaN
#
#             1992        1993        1994        1995       1996        1997  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# ...          ...         ...         ...         ...        ...         ...
# 7114         NaN         NaN         NaN         NaN        NaN         NaN
# 7115         NaN         NaN         NaN         NaN        NaN         NaN
# 7116         NaN         NaN         NaN         NaN        NaN         NaN
# 7117         NaN         NaN         NaN         NaN        NaN         NaN
# 7118         NaN         NaN         NaN         NaN        NaN         NaN
#
#       ...        2040     2045        2050     2055        2060        2070  \
# 0     ...  425.334009      NaN  460.999873      NaN  484.178829  492.704624
# 1     ...  254.601969      NaN  253.791865      NaN   270.46473  280.477734
# 2     ...  253.300442      NaN  252.454499      NaN  269.096264  279.093029
# 3     ...  239.794999      NaN  232.214116      NaN  248.994325   257.72526
# 4     ...  205.847732      NaN  198.896022      NaN  215.531464  224.808898
# ...   ...         ...      ...         ...      ...         ...         ...
# 7114  ...      1.1468   1.0248      0.9112   0.8971      0.8691      0.8122
# 7115  ...     95.4556  83.2434      70.855  71.7009     71.7427     69.5647
# 7116  ...     23.3591  21.8933     20.6224  20.0945      19.602     18.7858
# 7117  ...     58.6416  48.7633     38.5729  38.9534     38.7669     37.0805
# 7118  ...    104.8695  94.0495     83.5338  80.9232     78.4139      73.696
#
#             2080        2090        2100                        scenario
# 0     493.081016      477.74  458.001268     SSP2_int_lc_15|Baseline_CLE
# 1     285.729495  287.242139  285.347242         SSP2_int_lc_15|MFR_tech
# 2     284.342611  285.865296  283.997366      SSP2_int_lc_15|MFR_explore
# 3     264.433003  268.243567  269.414432        SSP2_int_lc_15|MFR_struc
# 4     232.398358  237.492262  240.051394     SSP2_int_lc_15|MFR_behavior
# ...          ...         ...         ...                             ...
# 7114      0.7691      0.7257      0.6893  Transport_NPi_Conv|MFR_develop
# 7115      66.244     62.2456     56.9063  Transport_NPi_Conv|MFR_develop
# 7116      18.131     17.9052     18.0274  Transport_NPi_Conv|MFR_develop
# 7117     33.9795     29.7616     25.0152  Transport_NPi_Conv|MFR_develop
# 7118     70.0332     67.8296     67.1864  Transport_NPi_Conv|MFR_develop
#
# [6102 rows x 46 columns]

# %%
gains_df.insert(loc=2, column='region', value='World')

# %%
gains_df
# Out:
#                      model          variable region        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# ...                    ...               ...    ...         ...         ...
# 7114  REMIND-Transport 2.1     Emissions|NH3  World         NaN         NaN
# 7115  REMIND-Transport 2.1     Emissions|NOx  World         NaN         NaN
# 7116  REMIND-Transport 2.1      Emissions|OC  World         NaN         NaN
# 7117  REMIND-Transport 2.1  Emissions|Sulfur  World         NaN         NaN
# 7118  REMIND-Transport 2.1     Emissions|VOC  World         NaN         NaN
#
#             1992        1993        1994        1995       1996  ...  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# ...          ...         ...         ...         ...        ...  ...
# 7114         NaN         NaN         NaN         NaN        NaN  ...
# 7115         NaN         NaN         NaN         NaN        NaN  ...
# 7116         NaN         NaN         NaN         NaN        NaN  ...
# 7117         NaN         NaN         NaN         NaN        NaN  ...
# 7118         NaN         NaN         NaN         NaN        NaN  ...
#
#             2040     2045        2050     2055        2060        2070  \
# 0     425.334009      NaN  460.999873      NaN  484.178829  492.704624
# 1     254.601969      NaN  253.791865      NaN   270.46473  280.477734
# 2     253.300442      NaN  252.454499      NaN  269.096264  279.093029
# 3     239.794999      NaN  232.214116      NaN  248.994325   257.72526
# 4     205.847732      NaN  198.896022      NaN  215.531464  224.808898
# ...          ...      ...         ...      ...         ...         ...
# 7114      1.1468   1.0248      0.9112   0.8971      0.8691      0.8122
# 7115     95.4556  83.2434      70.855  71.7009     71.7427     69.5647
# 7116     23.3591  21.8933     20.6224  20.0945      19.602     18.7858
# 7117     58.6416  48.7633     38.5729  38.9534     38.7669     37.0805
# 7118    104.8695  94.0495     83.5338  80.9232     78.4139      73.696
#
#             2080        2090        2100                        scenario
# 0     493.081016      477.74  458.001268     SSP2_int_lc_15|Baseline_CLE
# 1     285.729495  287.242139  285.347242         SSP2_int_lc_15|MFR_tech
# 2     284.342611  285.865296  283.997366      SSP2_int_lc_15|MFR_explore
# 3     264.433003  268.243567  269.414432        SSP2_int_lc_15|MFR_struc
# 4     232.398358  237.492262  240.051394     SSP2_int_lc_15|MFR_behavior
# ...          ...         ...         ...                             ...
# 7114      0.7691      0.7257      0.6893  Transport_NPi_Conv|MFR_develop
# 7115      66.244     62.2456     56.9063  Transport_NPi_Conv|MFR_develop
# 7116      18.131     17.9052     18.0274  Transport_NPi_Conv|MFR_develop
# 7117     33.9795     29.7616     25.0152  Transport_NPi_Conv|MFR_develop
# 7118     70.0332     67.8296     67.1864  Transport_NPi_Conv|MFR_develop
#
# [6102 rows x 47 columns]

# %%
gains_df["unit"] = ""
gains_df
# Out:
#                      model          variable region        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# ...                    ...               ...    ...         ...         ...
# 7114  REMIND-Transport 2.1     Emissions|NH3  World         NaN         NaN
# 7115  REMIND-Transport 2.1     Emissions|NOx  World         NaN         NaN
# 7116  REMIND-Transport 2.1      Emissions|OC  World         NaN         NaN
# 7117  REMIND-Transport 2.1  Emissions|Sulfur  World         NaN         NaN
# 7118  REMIND-Transport 2.1     Emissions|VOC  World         NaN         NaN
#
#             1992        1993        1994        1995       1996  ...     2045  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  ...      NaN
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  ...      NaN
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  ...      NaN
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  ...      NaN
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  ...      NaN
# ...          ...         ...         ...         ...        ...  ...      ...
# 7114         NaN         NaN         NaN         NaN        NaN  ...   1.0248
# 7115         NaN         NaN         NaN         NaN        NaN  ...  83.2434
# 7116         NaN         NaN         NaN         NaN        NaN  ...  21.8933
# 7117         NaN         NaN         NaN         NaN        NaN  ...  48.7633
# 7118         NaN         NaN         NaN         NaN        NaN  ...  94.0495
#
#             2050     2055        2060        2070        2080        2090  \
# 0     460.999873      NaN  484.178829  492.704624  493.081016      477.74
# 1     253.791865      NaN   270.46473  280.477734  285.729495  287.242139
# 2     252.454499      NaN  269.096264  279.093029  284.342611  285.865296
# 3     232.214116      NaN  248.994325   257.72526  264.433003  268.243567
# 4     198.896022      NaN  215.531464  224.808898  232.398358  237.492262
# ...          ...      ...         ...         ...         ...         ...
# 7114      0.9112   0.8971      0.8691      0.8122      0.7691      0.7257
# 7115      70.855  71.7009     71.7427     69.5647      66.244     62.2456
# 7116     20.6224  20.0945      19.602     18.7858      18.131     17.9052
# 7117     38.5729  38.9534     38.7669     37.0805     33.9795     29.7616
# 7118     83.5338  80.9232     78.4139      73.696     70.0332     67.8296
#
#             2100                        scenario unit
# 0     458.001268     SSP2_int_lc_15|Baseline_CLE
# 1     285.347242         SSP2_int_lc_15|MFR_tech
# 2     283.997366      SSP2_int_lc_15|MFR_explore
# 3     269.414432        SSP2_int_lc_15|MFR_struc
# 4     240.051394     SSP2_int_lc_15|MFR_behavior
# ...          ...                             ...  ...
# 7114      0.6893  Transport_NPi_Conv|MFR_develop
# 7115     56.9063  Transport_NPi_Conv|MFR_develop
# 7116     18.0274  Transport_NPi_Conv|MFR_develop
# 7117     25.0152  Transport_NPi_Conv|MFR_develop
# 7118     67.1864  Transport_NPi_Conv|MFR_develop
#
# [6102 rows x 48 columns]

# %%
unit_map = {
    "Emissions|BC": "Mt BC/yr",
    'Emissions|CH4': "Mt CH4/yr",
    'Emissions|CO': "Mt CO/yr",
#     'Emissions|CO2': 'Mt CO2/yr',
    'Emissions|N2O': 'kt N2O/yr',
    'Emissions|NH3': 'Mt NH3/yr',
    'Emissions|NOx': 'Mt NO2/yr',
    'Emissions|OC': 'Mt OC/yr',
    'Emissions|SF6': 'Mt SF6/yr',
    'Emissions|Sulfur': 'Mt SO2/yr',
    'Emissions|VOC': 'Mt VOC/yr'
}

# %%
for variable in gains_df["variable"].unique():
    gains_df.loc[gains_df["variable"]==variable, "unit"] = unit_map[variable]

# %%
cols = gains_df.columns.tolist()
cols = cols[0:1] + cols[-2:-1] + cols[2:0:-1] + cols[-1:] + cols[3:-2]
cols
# Out:
# ['model',
#  'scenario',
#  'region',
#  'variable',
#  'unit',
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2025,
#  2030,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2060,
#  2070,
#  2080,
#  2090,
#  2100]

# %%
gains_df = gains_df[cols]

# %%
gains_df
# Out:
#                      model                        scenario region  \
# 0     MESSAGEix-GLOBIOM_GE     SSP2_int_lc_15|Baseline_CLE  World
# 1     MESSAGEix-GLOBIOM_GE         SSP2_int_lc_15|MFR_tech  World
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15|MFR_explore  World
# 3     MESSAGEix-GLOBIOM_GE        SSP2_int_lc_15|MFR_struc  World
# 4     MESSAGEix-GLOBIOM_GE     SSP2_int_lc_15|MFR_behavior  World
# ...                    ...                             ...    ...
# 7114  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7115  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7116  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7117  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7118  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
#
#               variable       unit        1990        1991        1992  \
# 0        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# 1        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# 2        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# 3        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# 4        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# ...                ...        ...         ...         ...         ...
# 7114     Emissions|NH3  Mt NH3/yr         NaN         NaN         NaN
# 7115     Emissions|NOx  Mt NO2/yr         NaN         NaN         NaN
# 7116      Emissions|OC   Mt OC/yr         NaN         NaN         NaN
# 7117  Emissions|Sulfur  Mt SO2/yr         NaN         NaN         NaN
# 7118     Emissions|VOC  Mt VOC/yr         NaN         NaN         NaN
#
#             1993        1994  ...      2035        2040     2045        2050  \
# 0     296.988605  296.347795  ...       NaN  425.334009      NaN  460.999873
# 1     296.988605  296.347795  ...       NaN  254.601969      NaN  253.791865
# 2     296.988605  296.347795  ...       NaN  253.300442      NaN  252.454499
# 3     296.988605  296.347795  ...       NaN  239.794999      NaN  232.214116
# 4     296.988605  296.347795  ...       NaN  205.847732      NaN  198.896022
# ...          ...         ...  ...       ...         ...      ...         ...
# 7114         NaN         NaN  ...    1.2779      1.1468   1.0248      0.9112
# 7115         NaN         NaN  ...  106.8348     95.4556  83.2434      70.855
# 7116         NaN         NaN  ...    24.968     23.3591  21.8933     20.6224
# 7117         NaN         NaN  ...   68.7234     58.6416  48.7633     38.5729
# 7118         NaN         NaN  ...  115.5794    104.8695  94.0495     83.5338
#
#          2055        2060        2070        2080        2090        2100
# 0         NaN  484.178829  492.704624  493.081016      477.74  458.001268
# 1         NaN   270.46473  280.477734  285.729495  287.242139  285.347242
# 2         NaN  269.096264  279.093029  284.342611  285.865296  283.997366
# 3         NaN  248.994325   257.72526  264.433003  268.243567  269.414432
# 4         NaN  215.531464  224.808898  232.398358  237.492262  240.051394
# ...       ...         ...         ...         ...         ...         ...
# 7114   0.8971      0.8691      0.8122      0.7691      0.7257      0.6893
# 7115  71.7009     71.7427     69.5647      66.244     62.2456     56.9063
# 7116  20.0945      19.602     18.7858      18.131     17.9052     18.0274
# 7117  38.9534     38.7669     37.0805     33.9795     29.7616     25.0152
# 7118  80.9232     78.4139      73.696     70.0332     67.8296     67.1864
#
# [6102 rows x 48 columns]

# %%
biomass_df = pd.read_csv('../data/gfed4.1s_ch4_biomass_burning_1997-2020.csv', index_col=0)
biomass_df
# Out:
#           1990       1991      1992       1993       1994       1995  \
# CH4  11.279197  25.615438  9.827946  11.224433  21.106864  11.850119
#
#           1996       1997       1998       1999  ...       2011       2012  \
# CH4  10.788695  33.832226  17.668777  12.208482  ...  10.734526  12.939669
#
#           2013       2014       2015       2016       2017       2018  \
# CH4  10.588471  15.099539  20.116184  10.748002  11.220374  11.246223
#
#           2019       2020
# CH4  17.993842  11.489069
#
# [1 rows x 31 columns]

# %%
gains_df.loc[
    gains_df['variable']=='Emissions|CH4', 1990:2020
] = gains_df.loc[
    gains_df['variable']=='Emissions|CH4', 1990:2020
] + biomass_df.loc['CH4', :].values

# %%
gains_df
# Out:
#                      model                        scenario region  \
# 0     MESSAGEix-GLOBIOM_GE     SSP2_int_lc_15|Baseline_CLE  World
# 1     MESSAGEix-GLOBIOM_GE         SSP2_int_lc_15|MFR_tech  World
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15|MFR_explore  World
# 3     MESSAGEix-GLOBIOM_GE        SSP2_int_lc_15|MFR_struc  World
# 4     MESSAGEix-GLOBIOM_GE     SSP2_int_lc_15|MFR_behavior  World
# ...                    ...                             ...    ...
# 7114  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7115  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7116  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7117  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
# 7118  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_develop  World
#
#               variable       unit        1990        1991        1992  \
# 0        Emissions|CH4  Mt CH4/yr  319.010242  325.823192  306.473121
# 1        Emissions|CH4  Mt CH4/yr  319.010242  325.823192  306.473121
# 2        Emissions|CH4  Mt CH4/yr  319.010242  325.823192  306.473121
# 3        Emissions|CH4  Mt CH4/yr  319.010242  325.823192  306.473121
# 4        Emissions|CH4  Mt CH4/yr  319.010242  325.823192  306.473121
# ...                ...        ...         ...         ...         ...
# 7114     Emissions|NH3  Mt NH3/yr         NaN         NaN         NaN
# 7115     Emissions|NOx  Mt NO2/yr         NaN         NaN         NaN
# 7116      Emissions|OC   Mt OC/yr         NaN         NaN         NaN
# 7117  Emissions|Sulfur  Mt SO2/yr         NaN         NaN         NaN
# 7118     Emissions|VOC  Mt VOC/yr         NaN         NaN         NaN
#
#             1993        1994  ...      2035        2040     2045        2050  \
# 0     308.213038  317.454659  ...       NaN  425.334009      NaN  460.999873
# 1     308.213038  317.454659  ...       NaN  254.601969      NaN  253.791865
# 2     308.213038  317.454659  ...       NaN  253.300442      NaN  252.454499
# 3     308.213038  317.454659  ...       NaN  239.794999      NaN  232.214116
# 4     308.213038  317.454659  ...       NaN  205.847732      NaN  198.896022
# ...          ...         ...  ...       ...         ...      ...         ...
# 7114         NaN         NaN  ...    1.2779      1.1468   1.0248      0.9112
# 7115         NaN         NaN  ...  106.8348     95.4556  83.2434      70.855
# 7116         NaN         NaN  ...    24.968     23.3591  21.8933     20.6224
# 7117         NaN         NaN  ...   68.7234     58.6416  48.7633     38.5729
# 7118         NaN         NaN  ...  115.5794    104.8695  94.0495     83.5338
#
#          2055        2060        2070        2080        2090        2100
# 0         NaN  484.178829  492.704624  493.081016      477.74  458.001268
# 1         NaN   270.46473  280.477734  285.729495  287.242139  285.347242
# 2         NaN  269.096264  279.093029  284.342611  285.865296  283.997366
# 3         NaN  248.994325   257.72526  264.433003  268.243567  269.414432
# 4         NaN  215.531464  224.808898  232.398358  237.492262  240.051394
# ...       ...         ...         ...         ...         ...         ...
# 7114   0.8971      0.8691      0.8122      0.7691      0.7257      0.6893
# 7115  71.7009     71.7427     69.5647      66.244     62.2456     56.9063
# 7116  20.0945      19.602     18.7858      18.131     17.9052     18.0274
# 7117  38.9534     38.7669     37.0805     33.9795     29.7616     25.0152
# 7118  80.9232     78.4139      73.696     70.0332     67.8296     67.1864
#
# [6102 rows x 48 columns]

# %%
co2_df = pd.read_csv('../data/co2_fossil_afolu.csv')
co2_df
# Out:
#                          model                   scenario region  \
# 0    MESSAGEix-GLOBIOM_GEI 1.0             SSP2_int_lc_15  World
# 1    MESSAGEix-GLOBIOM_GEI 1.0             SSP2_int_lc_15  World
# 2    MESSAGEix-GLOBIOM_GEI 1.0             SSP2_int_lc_50  World
# 3    MESSAGEix-GLOBIOM_GEI 1.0             SSP2_int_lc_50  World
# 4    MESSAGEix-GLOBIOM_GEI 1.0             SSP2_int_mc_15  World
# ..                         ...                        ...    ...
# 221       REMIND-Transport 2.1  Transport_Budg1100_H2Push  World
# 222       REMIND-Transport 2.1         Transport_NDC_Conv  World
# 223       REMIND-Transport 2.1         Transport_NDC_Conv  World
# 224       REMIND-Transport 2.1         Transport_NPi_Conv  World
# 225       REMIND-Transport 2.1         Transport_NPi_Conv  World
#
#                                           variable       unit  1990  1991  \
# 0    Emissions|CO2|Energy and Industrial Processes  Mt CO2/yr   NaN   NaN
# 1                              Emissions|CO2|AFOLU  Mt CO2/yr   NaN   NaN
# 2    Emissions|CO2|Energy and Industrial Processes  Mt CO2/yr   NaN   NaN
# 3                              Emissions|CO2|AFOLU  Mt CO2/yr   NaN   NaN
# 4    Emissions|CO2|Energy and Industrial Processes  Mt CO2/yr   NaN   NaN
# ..                                             ...        ...   ...   ...
# 221                            Emissions|CO2|AFOLU  Mt CO2/yr   NaN   NaN
# 222  Emissions|CO2|Energy and Industrial Processes  Mt CO2/yr   NaN   NaN
# 223                            Emissions|CO2|AFOLU  Mt CO2/yr   NaN   NaN
# 224  Emissions|CO2|Energy and Industrial Processes  Mt CO2/yr   NaN   NaN
# 225                            Emissions|CO2|AFOLU  Mt CO2/yr   NaN   NaN
#
#      1992  1993  1994  ...        2035          2040        2045  \
# 0     NaN   NaN   NaN  ...         NaN  35681.112935         NaN
# 1     NaN   NaN   NaN  ...         NaN    946.861295         NaN
# 2     NaN   NaN   NaN  ...         NaN  22810.210637         NaN
# 3     NaN   NaN   NaN  ...         NaN    170.945937         NaN
# 4     NaN   NaN   NaN  ...         NaN  36858.674850         NaN
# ..    ...   ...   ...  ...         ...           ...         ...
# 221   NaN   NaN   NaN  ...   -248.7100   -217.873300   -131.6333
# 222   NaN   NaN   NaN  ...  34556.8846  31944.017200  30697.2082
# 223   NaN   NaN   NaN  ...   4403.2267   3727.056700   3342.0933
# 224   NaN   NaN   NaN  ...  41849.5292  43126.652800  45313.4674
# 225   NaN   NaN   NaN  ...   4403.2267   3727.056700   3342.0933
#
#              2050        2055          2060          2070          2080  \
# 0    31371.504102         NaN  21070.651310   9691.570964   3817.968869
# 1     -987.912049         NaN  -2797.108628  -3447.084897  -4196.042717
# 2    11709.435196         NaN   3023.081947  -2554.916767  -6487.792774
# 3    -1400.666788         NaN  -3379.021450  -3492.670670  -4119.149947
# 4    30625.570844         NaN  19532.363595   8823.292515   3010.948192
# ..            ...         ...           ...           ...           ...
# 221    -95.223300    -91.3000   -111.063300   -178.346700   -275.146700
# 222  29894.500700  29450.4611  29012.270400  27720.513700  27272.401400
# 223   3340.626700   3665.7133   4067.616700   3893.560000   2774.530000
# 224  48118.249000  51226.6726  53925.096800  57729.537500  59184.605900
# 225   3340.626700   3665.7133   4067.616700   3893.560000   2774.530000
#
#              2090          2100
# 0    -2248.291820  -6292.777066
# 1    -5019.684264  -4453.606015
# 2    -9652.116579 -11801.725595
# 3    -4849.949743  -4395.481429
# 4    -2617.872540  -6334.733807
# ..            ...           ...
# 221   -319.550000   -262.496700
# 222  26245.377000  24628.088600
# 223   1340.606700    459.176700
# 224  56656.593300  51926.259900
# 225   1340.606700    459.176700
#
# [226 rows x 48 columns]

# %%
new_df = pd.DataFrame(columns = gains_df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [model, scenario, region, variable, unit, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2070, 2080, 2090, 2100]
# Index: []
#
# [0 rows x 48 columns]

# %%
idx = gains_df.index.max() + 1
idx
# Out:
# 7119

# %%
for ms, data in tqdm(gains_df.groupby(["model", "scenario"])):
#    print(ms[1].split("|")[0])
#     print(co2_df[(co2_df['Model'].str.startswith(ms[0])) & (co2_df['Scenario'].str[:30] == ms[1].split("|")[0])])
#     print(co2_df[(co2_df['Model'].str.startswith(ms[0])) & (co2_df['Scenario'].str[:30] == ms[1].split("|")[0])& (co2_df['Variable']=='Emissions|CO2|Energy and Industrial Processes')])
    
#     for scenario in methane_scenarios:
        new_df.loc[idx, :] = co2_df[
            (co2_df['model'].str.startswith(ms[0])) & 
            (co2_df['scenario'].str[:30] == ms[1].split("|")[0]) & 
            (co2_df['variable']=='Emissions|CO2|Energy and Industrial Processes')
        ].values
        new_df.loc[idx, 'model']=ms[0]
        new_df.loc[idx, 'scenario']=ms[1]

        new_df.loc[idx+1, :] = co2_df[
            (co2_df['model'].str.startswith(ms[0])) & 
            (co2_df['scenario'].str[:30] == ms[1].split("|")[0]) & 
            (co2_df['variable']=='Emissions|CO2|AFOLU')
        ].values
        new_df.loc[idx+1, 'model']=ms[0]
        new_df.loc[idx+1, 'scenario']=ms[1]

        idx = idx + 2
# Out:
#   0%|          | 0/678 [00:00<?, ?it/s]

# %%
gains_df = pd.concat((gains_df, new_df))

# %%
gains_df.sort_values(by = ['model', 'scenario', 'variable'], inplace=True)

# %%
gains_df.to_csv('../data/gains_scenarios_pyam_format.csv', index=False)
