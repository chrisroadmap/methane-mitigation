# %% [markdown]
# # Consolidate GAINS emissions
#
# - Add biomass burning CH4 to GAINS inventories
# - reorganise emissions files to format that can be used in harmonization
# - harmonization year 1990 for methane, 2020 for other emissions with SSP245

# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# %%
gains_df = pd.read_excel('../data/CH4_GAINS-IPCC_scenarios_4Feb2023_toChrisSmith.xlsx')

# %%
gains_df
# Out:
#        sc                 model            scenario            MPscen  \
# 0     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE
# 1     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech
# 2     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore
# 3     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc
# 4     597  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior
# ...   ...                   ...                 ...               ...
# 2009  833  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC
# 2010  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|SF6
# 2011  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|PFC
# 2012  833  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur
# 2013  833  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC
#
#            y1990       y1991       y1992       y1993       y1994       y1995  \
# 0     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 1     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 2     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 3     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 4     307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# ...          ...         ...         ...         ...         ...         ...
# 2009         NaN         NaN         NaN         NaN         NaN         NaN
# 2010         NaN         NaN         NaN         NaN         NaN         NaN
# 2011         NaN         NaN         NaN         NaN         NaN         NaN
# 2012         NaN         NaN         NaN         NaN         NaN         NaN
# 2013         NaN         NaN         NaN         NaN         NaN         NaN
#
#       ...       y2020       y2030       y2040       y2050       y2060  \
# 0     ...  358.927789  384.430987  425.334009  460.999873  484.178829
# 1     ...  358.927789  262.052740  254.601969  253.791865  270.464730
# 2     ...  358.927789  260.660953  253.300442  252.454499  269.096264
# 3     ...  358.927789  255.888233  239.794999  232.214116  248.994325
# 4     ...  358.927789  218.455205  205.847732  198.896022  215.531464
# ...   ...         ...         ...         ...         ...         ...
# 2009  ...   28.297700   26.570700   23.284000   20.561200   19.554900
# 2010  ...    5.508500    5.284300    4.903500    4.333200    1.780700
# 2011  ...   29.943000   21.475000   16.045700   10.174500    6.262600
# 2012  ...   75.363200   73.479700   54.663900   35.375200   36.347600
# 2013  ...  127.895100  125.199200  104.301900   83.007000   77.945900
#
#            y2070       y2080       y2090       y2100  rank
# 0     492.704624  493.081016  477.740000  458.001268     1
# 1     280.477734  285.729495  287.242139  285.347242     2
# 2     279.093029  284.342611  285.865296  283.997366     3
# 3     257.725260  264.433003  268.243567  269.414432     4
# 4     224.808898  232.398358  237.492262  240.051394     5
# ...          ...         ...         ...         ...   ...
# 2009   18.750800   18.105400   17.886200   18.013700    17
# 2010    1.755400    1.719600    1.490300    1.393200    18
# 2011    6.019900    5.639300    4.811800    4.719900    18
# 2012   35.298800   32.697700   28.805600   24.323300    19
# 2013   73.290900   69.689400   67.528600   66.931100    20
#
# [2014 rows x 44 columns]

# %%
gains_df["MPscen"].unique()
# Out:
# array(['Baseline_CLE', 'MFR_tech', 'MFR_explore', 'MFR_struc',
#        'MFR_behavior', 'MFR_develop', 'Emissions|BC', 'Emissions|CO',
#        'Emissions|CO2', 'Emissions|HFC', 'Emissions|N2O', 'Emissions|NH3',
#        'Emissions|NOx', 'Emissions|OC', 'Emissions|SF6',
#        'Emissions|Sulfur', 'Emissions|VOC', 'Emissions|PFC'], dtype=object)

# %%
gains_df.drop(columns=["sc", "rank"], inplace=True)  # adds nothing

# %%
gains_df.drop(
    gains_df.loc[
        gains_df['MPscen'].isin(
            (
                'Emissions|PFC',
                'Emissions|HFC'
            ),
        )
    ].index,
inplace=True)  # no aggregates please

# %%
gains_df
# Out:
#                      model            scenario            MPscen       y1990  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE  307.731045
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech  307.731045
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore  307.731045
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc  307.731045
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior  307.731045
# ...                    ...                 ...               ...         ...
# 2008  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NOx         NaN
# 2009  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC         NaN
# 2010  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|SF6         NaN
# 2012  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur         NaN
# 2013  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC         NaN
#
#            y1991       y1992       y1993       y1994       y1995      y1996  \
# 0     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 1     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 2     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 3     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# 4     300.207754  296.645175  296.988605  296.347795  294.214088  294.45247
# ...          ...         ...         ...         ...         ...        ...
# 2008         NaN         NaN         NaN         NaN         NaN        NaN
# 2009         NaN         NaN         NaN         NaN         NaN        NaN
# 2010         NaN         NaN         NaN         NaN         NaN        NaN
# 2012         NaN         NaN         NaN         NaN         NaN        NaN
# 2013         NaN         NaN         NaN         NaN         NaN        NaN
#
#       ...       y2019       y2020       y2030       y2040       y2050  \
# 0     ...  357.894529  358.927789  384.430987  425.334009  460.999873
# 1     ...  357.894529  358.927789  262.052740  254.601969  253.791865
# 2     ...  357.894529  358.927789  260.660953  253.300442  252.454499
# 3     ...  357.894529  358.927789  255.888233  239.794999  232.214116
# 4     ...  357.894529  358.927789  218.455205  205.847732  198.896022
# ...   ...         ...         ...         ...         ...         ...
# 2008  ...         NaN  104.621900  104.908200   84.152400   60.475100
# 2009  ...         NaN   28.297700   26.570700   23.284000   20.561200
# 2010  ...         NaN    5.508500    5.284300    4.903500    4.333200
# 2012  ...         NaN   75.363200   73.479700   54.663900   35.375200
# 2013  ...         NaN  127.895100  125.199200  104.301900   83.007000
#
#            y2060       y2070       y2080       y2090       y2100
# 0     484.178829  492.704624  493.081016  477.740000  458.001268
# 1     270.464730  280.477734  285.729495  287.242139  285.347242
# 2     269.096264  279.093029  284.342611  285.865296  283.997366
# 3     248.994325  257.725260  264.433003  268.243567  269.414432
# 4     215.531464  224.808898  232.398358  237.492262  240.051394
# ...          ...         ...         ...         ...         ...
# 2008   62.634500   61.768900   59.772100   56.696400   52.260200
# 2009   19.554900   18.750800   18.105400   17.886200   18.013700
# 2010    1.780700    1.755400    1.719600    1.490300    1.393200
# 2012   36.347600   35.298800   32.697700   28.805600   24.323300
# 2013   77.945900   73.290900   69.689400   67.528600   66.931100
#
# [1808 rows x 42 columns]

# %%
gains_df.insert(loc=3, column="variable", value="Emissions|CH4")

# %%
gains_df
# Out:
#                      model            scenario            MPscen  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      Baseline_CLE
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15          MFR_tech
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15       MFR_explore
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15         MFR_struc
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_behavior
# ...                    ...                 ...               ...
# 2008  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|NOx
# 2009  REMIND-Transport 2.1  Transport_NPi_Conv      Emissions|OC
# 2010  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|SF6
# 2012  REMIND-Transport 2.1  Transport_NPi_Conv  Emissions|Sulfur
# 2013  REMIND-Transport 2.1  Transport_NPi_Conv     Emissions|VOC
#
#            variable       y1990       y1991       y1992       y1993  \
# 0     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 1     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 2     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 3     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 4     Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# ...             ...         ...         ...         ...         ...
# 2008  Emissions|CH4         NaN         NaN         NaN         NaN
# 2009  Emissions|CH4         NaN         NaN         NaN         NaN
# 2010  Emissions|CH4         NaN         NaN         NaN         NaN
# 2012  Emissions|CH4         NaN         NaN         NaN         NaN
# 2013  Emissions|CH4         NaN         NaN         NaN         NaN
#
#            y1994       y1995  ...       y2019       y2020       y2030  \
# 0     296.347795  294.214088  ...  357.894529  358.927789  384.430987
# 1     296.347795  294.214088  ...  357.894529  358.927789  262.052740
# 2     296.347795  294.214088  ...  357.894529  358.927789  260.660953
# 3     296.347795  294.214088  ...  357.894529  358.927789  255.888233
# 4     296.347795  294.214088  ...  357.894529  358.927789  218.455205
# ...          ...         ...  ...         ...         ...         ...
# 2008         NaN         NaN  ...         NaN  104.621900  104.908200
# 2009         NaN         NaN  ...         NaN   28.297700   26.570700
# 2010         NaN         NaN  ...         NaN    5.508500    5.284300
# 2012         NaN         NaN  ...         NaN   75.363200   73.479700
# 2013         NaN         NaN  ...         NaN  127.895100  125.199200
#
#            y2040       y2050       y2060       y2070       y2080       y2090  \
# 0     425.334009  460.999873  484.178829  492.704624  493.081016  477.740000
# 1     254.601969  253.791865  270.464730  280.477734  285.729495  287.242139
# 2     253.300442  252.454499  269.096264  279.093029  284.342611  285.865296
# 3     239.794999  232.214116  248.994325  257.725260  264.433003  268.243567
# 4     205.847732  198.896022  215.531464  224.808898  232.398358  237.492262
# ...          ...         ...         ...         ...         ...         ...
# 2008   84.152400   60.475100   62.634500   61.768900   59.772100   56.696400
# 2009   23.284000   20.561200   19.554900   18.750800   18.105400   17.886200
# 2010    4.903500    4.333200    1.780700    1.755400    1.719600    1.490300
# 2012   54.663900   35.375200   36.347600   35.298800   32.697700   28.805600
# 2013  104.301900   83.007000   77.945900   73.290900   69.689400   67.528600
#
#            y2100
# 0     458.001268
# 1     285.347242
# 2     283.997366
# 3     269.414432
# 4     240.051394
# ...          ...
# 2008   52.260200
# 2009   18.013700
# 2010    1.393200
# 2012   24.323300
# 2013   66.931100
#
# [1808 rows x 43 columns]

# %%
#lambda x: x['col3'] if x['col1'] < x['col2'] else x['col1'], axis=1

gains_df["variable"] = gains_df.apply(
    lambda x: x["MPscen"] if x["MPscen"].startswith("Emissions") else x["variable"], axis=1
)

# %%
gains_df["MPscen"] = gains_df.apply(
    lambda x: "" if x["MPscen"].startswith("Emissions") else x["MPscen"], axis=1
)

# %%
gains_df.head(16)
# Out:
#                    model        scenario        MPscen          variable  \
# 0   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15  Baseline_CLE     Emissions|CH4
# 1   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15      MFR_tech     Emissions|CH4
# 2   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15   MFR_explore     Emissions|CH4
# 3   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15     MFR_struc     Emissions|CH4
# 4   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15  MFR_behavior     Emissions|CH4
# 5   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15   MFR_develop     Emissions|CH4
# 6   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|BC
# 7   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|CO
# 8   MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|CO2
# 10  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|N2O
# 11  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|NH3
# 12  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|NOx
# 13  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                    Emissions|OC
# 14  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|SF6
# 15  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                Emissions|Sulfur
# 16  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15                   Emissions|VOC
#
#          y1990       y1991       y1992       y1993       y1994       y1995  \
# 0   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 1   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 2   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 3   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 4   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 5   307.731045  300.207754  296.645175  296.988605  296.347795  294.214088
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN         NaN
#
#     ...       y2019         y2020         y2030         y2040         y2050  \
# 0   ...  357.894529    358.927789    384.430987    425.334009    460.999873
# 1   ...  357.894529    358.927789    262.052740    254.601969    253.791865
# 2   ...  357.894529    358.927789    260.660953    253.300442    252.454499
# 3   ...  357.894529    358.927789    255.888233    239.794999    232.214116
# 4   ...  357.894529    358.927789    218.455205    205.847732    198.896022
# 5   ...  357.894529    358.927789    212.681895    200.365945    194.735280
# 6   ...         NaN      5.863179      5.362202      4.720507      3.919058
# 7   ...         NaN    766.549060    696.955610    604.059403    484.524992
# 8   ...         NaN  41727.746295  38983.471888  35823.979785  29656.727666
# 10  ...         NaN   9557.825391  10204.847680  10345.756187   9848.128349
# 11  ...         NaN     49.707085     50.436112     49.116823     45.356468
# 12  ...         NaN     86.987685     78.400419     67.622479     54.941436
# 13  ...         NaN     29.411093     25.668639     22.274479     18.744503
# 14  ...         NaN      8.799238      3.448027      3.690082      3.433429
# 15  ...         NaN     70.112121     60.993661     47.792637     34.749965
# 16  ...         NaN    171.788069    161.156838    147.261130    128.024421
#
#            y2060        y2070        y2080        y2090         y2100
# 0     484.178829   492.704624   493.081016   477.740000    458.001268
# 1     270.464730   280.477734   285.729495   287.242139    285.347242
# 2     269.096264   279.093029   284.342611   285.865296    283.997366
# 3     248.994325   257.725260   264.433003   268.243567    269.414432
# 4     215.531464   224.808898   232.398358   237.492262    240.051394
# 5     210.639939   219.204814   226.080483   230.344132    231.991915
# 6       3.225779     2.656437     2.139878     1.734696      1.665407
# 7     388.857895   318.078998   252.947654   214.062545    193.998581
# 8   17594.267719  5568.213731 -1044.763481 -7943.961345 -11257.178510
# 10   9429.984531  8900.429089  8040.052627  7625.449910   7215.610388
# 11     42.760863    37.994416    34.389574    31.704919     29.309005
# 12     44.177532    37.424504    32.412283    26.326724     22.018200
# 13     15.838631    13.195844    10.474288     8.731467      8.144096
# 14      3.067717     2.392265     2.049605     1.699540      1.475520
# 15     27.085388    23.338809    20.957153    18.644777     16.719822
# 16    111.030632    97.769597    83.631288    73.577081     69.681743
#
# [16 rows x 43 columns]

# %%
new_df = pd.DataFrame(columns = gains_df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [model, scenario, MPscen, variable, y1990, y1991, y1992, y1993, y1994, y1995, y1996, y1997, y1998, y1999, y2000, y2001, y2002, y2003, y2004, y2005, y2006, y2007, y2008, y2009, y2010, y2011, y2012, y2013, y2014, y2015, y2016, y2017, y2018, y2019, y2020, y2030, y2040, y2050, y2060, y2070, y2080, y2090, y2100]
# Index: []
#
# [0 rows x 43 columns]

# %%
# assign new unique index to first new element
idx = gains_df.index.max() + 1
idx
# Out:
# 2014

# %%
for ms, data in tqdm(gains_df.groupby(["model", "scenario"])):
    #print(gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])])
    
    for MPscen in data["MPscen"].unique():
        if MPscen != "":
            for variable in np.delete(data["variable"].unique(), np.where(data["variable"].unique()=='Emissions|CH4')):
                new_df.loc[idx, :] = gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["variable"]==variable)].values
                new_df.loc[idx, 'MPscen'] = MPscen
                #print(gains_df.loc[
                #    (gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["MPscen"]==MPscen)
                #])
                #new_df.loc
                #print(gains_df.loc[(gains_df["model"]==ms[0])&(gains_df["scenario"]==ms[1])&(gains_df["variable"]==variable)])
                idx = idx + 1
# Out:
#   0%|          | 0/113 [00:00<?, ?it/s]

# %%
new_df
# Out:
#                      model            scenario        MPscen  \
# 2014  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 2015  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 2016  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 2017  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 2018  MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# ...                    ...                 ...           ...
# 8789  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8790  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8791  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8792  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8793  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
#
#               variable y1990 y1991 y1992 y1993 y1994 y1995  ... y2019  \
# 2014      Emissions|BC   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2015      Emissions|CO   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2016     Emissions|CO2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2017     Emissions|N2O   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2018     Emissions|NH3   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...                ...   ...   ...   ...   ...   ...   ...  ...   ...
# 8789     Emissions|NOx   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8790      Emissions|OC   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8791     Emissions|SF6   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8792  Emissions|Sulfur   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 8793     Emissions|VOC   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#              y2020         y2030         y2040         y2050         y2060  \
# 2014      5.863179      5.362202      4.720507      3.919058      3.225779
# 2015     766.54906     696.95561    604.059403    484.524992    388.857895
# 2016  41727.746295  38983.471888  35823.979785  29656.727666  17594.267719
# 2017   9557.825391   10204.84768  10345.756187   9848.128349   9429.984531
# 2018     49.707085     50.436112     49.116823     45.356468     42.760863
# ...            ...           ...           ...           ...           ...
# 8789      104.6219      104.9082       84.1524       60.4751       62.6345
# 8790       28.2977       26.5707        23.284       20.5612       19.5549
# 8791        5.5085        5.2843        4.9035        4.3332        1.7807
# 8792       75.3632       73.4797       54.6639       35.3752       36.3476
# 8793      127.8951      125.1992      104.3019        83.007       77.9459
#
#             y2070        y2080        y2090        y2100
# 2014     2.656437     2.139878     1.734696     1.665407
# 2015   318.078998   252.947654   214.062545   193.998581
# 2016  5568.213731 -1044.763481 -7943.961345 -11257.17851
# 2017  8900.429089  8040.052627   7625.44991  7215.610388
# 2018    37.994416    34.389574    31.704919    29.309005
# ...           ...          ...          ...          ...
# 8789      61.7689      59.7721      56.6964      52.2602
# 8790      18.7508      18.1054      17.8862      18.0137
# 8791       1.7554       1.7196       1.4903       1.3932
# 8792      35.2988      32.6977      28.8056      24.3233
# 8793      73.2909      69.6894      67.5286      66.9311
#
# [6780 rows x 43 columns]

# %%
gains_df = pd.concat((gains_df, new_df))

# %%
gains_df["MPscen"].unique()
# Out:
# array(['Baseline_CLE', 'MFR_tech', 'MFR_explore', 'MFR_struc',
#        'MFR_behavior', 'MFR_develop', ''], dtype=object)

# %%
gains_df.drop(gains_df[gains_df.MPscen == ""].index, inplace=True)

# %%
gains_df['scen'] = gains_df['scenario'] + '|' + gains_df['MPscen']

# %%
gains_df
# Out:
#                      model            scenario        MPscen  \
# 0     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  Baseline_CLE
# 1     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15      MFR_tech
# 2     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15   MFR_explore
# 3     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15     MFR_struc
# 4     MESSAGEix-GLOBIOM_GE      SSP2_int_lc_15  MFR_behavior
# ...                    ...                 ...           ...
# 8789  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8790  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8791  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8792  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
# 8793  REMIND-Transport 2.1  Transport_NPi_Conv   MFR_develop
#
#               variable       y1990       y1991       y1992       y1993  \
# 0        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 1        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 2        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 3        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# 4        Emissions|CH4  307.731045  300.207754  296.645175  296.988605
# ...                ...         ...         ...         ...         ...
# 8789     Emissions|NOx         NaN         NaN         NaN         NaN
# 8790      Emissions|OC         NaN         NaN         NaN         NaN
# 8791     Emissions|SF6         NaN         NaN         NaN         NaN
# 8792  Emissions|Sulfur         NaN         NaN         NaN         NaN
# 8793     Emissions|VOC         NaN         NaN         NaN         NaN
#
#            y1994       y1995  ...       y2020       y2030       y2040  \
# 0     296.347795  294.214088  ...  358.927789  384.430987  425.334009
# 1     296.347795  294.214088  ...  358.927789   262.05274  254.601969
# 2     296.347795  294.214088  ...  358.927789  260.660953  253.300442
# 3     296.347795  294.214088  ...  358.927789  255.888233  239.794999
# 4     296.347795  294.214088  ...  358.927789  218.455205  205.847732
# ...          ...         ...  ...         ...         ...         ...
# 8789         NaN         NaN  ...    104.6219    104.9082     84.1524
# 8790         NaN         NaN  ...     28.2977     26.5707      23.284
# 8791         NaN         NaN  ...      5.5085      5.2843      4.9035
# 8792         NaN         NaN  ...     75.3632     73.4797     54.6639
# 8793         NaN         NaN  ...    127.8951    125.1992    104.3019
#
#            y2050       y2060       y2070       y2080       y2090       y2100  \
# 0     460.999873  484.178829  492.704624  493.081016      477.74  458.001268
# 1     253.791865   270.46473  280.477734  285.729495  287.242139  285.347242
# 2     252.454499  269.096264  279.093029  284.342611  285.865296  283.997366
# 3     232.214116  248.994325   257.72526  264.433003  268.243567  269.414432
# 4     198.896022  215.531464  224.808898  232.398358  237.492262  240.051394
# ...          ...         ...         ...         ...         ...         ...
# 8789     60.4751     62.6345     61.7689     59.7721     56.6964     52.2602
# 8790     20.5612     19.5549     18.7508     18.1054     17.8862     18.0137
# 8791      4.3332      1.7807      1.7554      1.7196      1.4903      1.3932
# 8792     35.3752     36.3476     35.2988     32.6977     28.8056     24.3233
# 8793      83.007     77.9459     73.2909     69.6894     67.5286     66.9311
#
#                                 scen
# 0        SSP2_int_lc_15|Baseline_CLE
# 1            SSP2_int_lc_15|MFR_tech
# 2         SSP2_int_lc_15|MFR_explore
# 3           SSP2_int_lc_15|MFR_struc
# 4        SSP2_int_lc_15|MFR_behavior
# ...                              ...
# 8789  Transport_NPi_Conv|MFR_develop
# 8790  Transport_NPi_Conv|MFR_develop
# 8791  Transport_NPi_Conv|MFR_develop
# 8792  Transport_NPi_Conv|MFR_develop
# 8793  Transport_NPi_Conv|MFR_develop
#
# [7458 rows x 44 columns]

# %%
gains_df.drop(columns = ['scenario', 'MPscen'], inplace=True)

# %%
gains_df.rename(columns={"scen": "scenario"}, inplace=True)

# %%
years = list(range(1990, 2020)) + list(range(2020, 2110, 10))
years
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2030,
#  2040,
#  2050,
#  2060,
#  2070,
#  2080,
#  2090,
#  2100]

# %%
gains_df.rename(columns={f'y{year}': year for year in years}, inplace=True)

# %%
gains_df
# Out:
#                      model          variable        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  307.731045  300.207754
# ...                    ...               ...         ...         ...
# 8789  REMIND-Transport 2.1     Emissions|NOx         NaN         NaN
# 8790  REMIND-Transport 2.1      Emissions|OC         NaN         NaN
# 8791  REMIND-Transport 2.1     Emissions|SF6         NaN         NaN
# 8792  REMIND-Transport 2.1  Emissions|Sulfur         NaN         NaN
# 8793  REMIND-Transport 2.1     Emissions|VOC         NaN         NaN
#
#             1992        1993        1994        1995       1996        1997  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  293.629159
# ...          ...         ...         ...         ...        ...         ...
# 8789         NaN         NaN         NaN         NaN        NaN         NaN
# 8790         NaN         NaN         NaN         NaN        NaN         NaN
# 8791         NaN         NaN         NaN         NaN        NaN         NaN
# 8792         NaN         NaN         NaN         NaN        NaN         NaN
# 8793         NaN         NaN         NaN         NaN        NaN         NaN
#
#       ...        2020        2030        2040        2050        2060  \
# 0     ...  358.927789  384.430987  425.334009  460.999873  484.178829
# 1     ...  358.927789   262.05274  254.601969  253.791865   270.46473
# 2     ...  358.927789  260.660953  253.300442  252.454499  269.096264
# 3     ...  358.927789  255.888233  239.794999  232.214116  248.994325
# 4     ...  358.927789  218.455205  205.847732  198.896022  215.531464
# ...   ...         ...         ...         ...         ...         ...
# 8789  ...    104.6219    104.9082     84.1524     60.4751     62.6345
# 8790  ...     28.2977     26.5707      23.284     20.5612     19.5549
# 8791  ...      5.5085      5.2843      4.9035      4.3332      1.7807
# 8792  ...     75.3632     73.4797     54.6639     35.3752     36.3476
# 8793  ...    127.8951    125.1992    104.3019      83.007     77.9459
#
#             2070        2080        2090        2100  \
# 0     492.704624  493.081016      477.74  458.001268
# 1     280.477734  285.729495  287.242139  285.347242
# 2     279.093029  284.342611  285.865296  283.997366
# 3      257.72526  264.433003  268.243567  269.414432
# 4     224.808898  232.398358  237.492262  240.051394
# ...          ...         ...         ...         ...
# 8789     61.7689     59.7721     56.6964     52.2602
# 8790     18.7508     18.1054     17.8862     18.0137
# 8791      1.7554      1.7196      1.4903      1.3932
# 8792     35.2988     32.6977     28.8056     24.3233
# 8793     73.2909     69.6894     67.5286     66.9311
#
#                             scenario
# 0        SSP2_int_lc_15|Baseline_CLE
# 1            SSP2_int_lc_15|MFR_tech
# 2         SSP2_int_lc_15|MFR_explore
# 3           SSP2_int_lc_15|MFR_struc
# 4        SSP2_int_lc_15|MFR_behavior
# ...                              ...
# 8789  Transport_NPi_Conv|MFR_develop
# 8790  Transport_NPi_Conv|MFR_develop
# 8791  Transport_NPi_Conv|MFR_develop
# 8792  Transport_NPi_Conv|MFR_develop
# 8793  Transport_NPi_Conv|MFR_develop
#
# [7458 rows x 42 columns]

# %%
gains_df.insert(loc=2, column='region', value='World')

# %%
gains_df
# Out:
#                      model          variable region        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# ...                    ...               ...    ...         ...         ...
# 8789  REMIND-Transport 2.1     Emissions|NOx  World         NaN         NaN
# 8790  REMIND-Transport 2.1      Emissions|OC  World         NaN         NaN
# 8791  REMIND-Transport 2.1     Emissions|SF6  World         NaN         NaN
# 8792  REMIND-Transport 2.1  Emissions|Sulfur  World         NaN         NaN
# 8793  REMIND-Transport 2.1     Emissions|VOC  World         NaN         NaN
#
#             1992        1993        1994        1995       1996  ...  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# ...          ...         ...         ...         ...        ...  ...
# 8789         NaN         NaN         NaN         NaN        NaN  ...
# 8790         NaN         NaN         NaN         NaN        NaN  ...
# 8791         NaN         NaN         NaN         NaN        NaN  ...
# 8792         NaN         NaN         NaN         NaN        NaN  ...
# 8793         NaN         NaN         NaN         NaN        NaN  ...
#
#             2020        2030        2040        2050        2060        2070  \
# 0     358.927789  384.430987  425.334009  460.999873  484.178829  492.704624
# 1     358.927789   262.05274  254.601969  253.791865   270.46473  280.477734
# 2     358.927789  260.660953  253.300442  252.454499  269.096264  279.093029
# 3     358.927789  255.888233  239.794999  232.214116  248.994325   257.72526
# 4     358.927789  218.455205  205.847732  198.896022  215.531464  224.808898
# ...          ...         ...         ...         ...         ...         ...
# 8789    104.6219    104.9082     84.1524     60.4751     62.6345     61.7689
# 8790     28.2977     26.5707      23.284     20.5612     19.5549     18.7508
# 8791      5.5085      5.2843      4.9035      4.3332      1.7807      1.7554
# 8792     75.3632     73.4797     54.6639     35.3752     36.3476     35.2988
# 8793    127.8951    125.1992    104.3019      83.007     77.9459     73.2909
#
#             2080        2090        2100                        scenario
# 0     493.081016      477.74  458.001268     SSP2_int_lc_15|Baseline_CLE
# 1     285.729495  287.242139  285.347242         SSP2_int_lc_15|MFR_tech
# 2     284.342611  285.865296  283.997366      SSP2_int_lc_15|MFR_explore
# 3     264.433003  268.243567  269.414432        SSP2_int_lc_15|MFR_struc
# 4     232.398358  237.492262  240.051394     SSP2_int_lc_15|MFR_behavior
# ...          ...         ...         ...                             ...
# 8789     59.7721     56.6964     52.2602  Transport_NPi_Conv|MFR_develop
# 8790     18.1054     17.8862     18.0137  Transport_NPi_Conv|MFR_develop
# 8791      1.7196      1.4903      1.3932  Transport_NPi_Conv|MFR_develop
# 8792     32.6977     28.8056     24.3233  Transport_NPi_Conv|MFR_develop
# 8793     69.6894     67.5286     66.9311  Transport_NPi_Conv|MFR_develop
#
# [7458 rows x 43 columns]

# %%
gains_df["unit"] = ""
gains_df
# Out:
#                      model          variable region        1990        1991  \
# 0     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 1     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 2     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 3     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# 4     MESSAGEix-GLOBIOM_GE     Emissions|CH4  World  307.731045  300.207754
# ...                    ...               ...    ...         ...         ...
# 8789  REMIND-Transport 2.1     Emissions|NOx  World         NaN         NaN
# 8790  REMIND-Transport 2.1      Emissions|OC  World         NaN         NaN
# 8791  REMIND-Transport 2.1     Emissions|SF6  World         NaN         NaN
# 8792  REMIND-Transport 2.1  Emissions|Sulfur  World         NaN         NaN
# 8793  REMIND-Transport 2.1     Emissions|VOC  World         NaN         NaN
#
#             1992        1993        1994        1995       1996  ...  \
# 0     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 1     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 2     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 3     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# 4     296.645175  296.988605  296.347795  294.214088  294.45247  ...
# ...          ...         ...         ...         ...        ...  ...
# 8789         NaN         NaN         NaN         NaN        NaN  ...
# 8790         NaN         NaN         NaN         NaN        NaN  ...
# 8791         NaN         NaN         NaN         NaN        NaN  ...
# 8792         NaN         NaN         NaN         NaN        NaN  ...
# 8793         NaN         NaN         NaN         NaN        NaN  ...
#
#             2030        2040        2050        2060        2070        2080  \
# 0     384.430987  425.334009  460.999873  484.178829  492.704624  493.081016
# 1      262.05274  254.601969  253.791865   270.46473  280.477734  285.729495
# 2     260.660953  253.300442  252.454499  269.096264  279.093029  284.342611
# 3     255.888233  239.794999  232.214116  248.994325   257.72526  264.433003
# 4     218.455205  205.847732  198.896022  215.531464  224.808898  232.398358
# ...          ...         ...         ...         ...         ...         ...
# 8789    104.9082     84.1524     60.4751     62.6345     61.7689     59.7721
# 8790     26.5707      23.284     20.5612     19.5549     18.7508     18.1054
# 8791      5.2843      4.9035      4.3332      1.7807      1.7554      1.7196
# 8792     73.4797     54.6639     35.3752     36.3476     35.2988     32.6977
# 8793    125.1992    104.3019      83.007     77.9459     73.2909     69.6894
#
#             2090        2100                        scenario unit
# 0         477.74  458.001268     SSP2_int_lc_15|Baseline_CLE
# 1     287.242139  285.347242         SSP2_int_lc_15|MFR_tech
# 2     285.865296  283.997366      SSP2_int_lc_15|MFR_explore
# 3     268.243567  269.414432        SSP2_int_lc_15|MFR_struc
# 4     237.492262  240.051394     SSP2_int_lc_15|MFR_behavior
# ...          ...         ...                             ...  ...
# 8789     56.6964     52.2602  Transport_NPi_Conv|MFR_develop
# 8790     17.8862     18.0137  Transport_NPi_Conv|MFR_develop
# 8791      1.4903      1.3932  Transport_NPi_Conv|MFR_develop
# 8792     28.8056     24.3233  Transport_NPi_Conv|MFR_develop
# 8793     67.5286     66.9311  Transport_NPi_Conv|MFR_develop
#
# [7458 rows x 44 columns]

# %%
unit_map = {
    "Emissions|BC": "Mt BC/yr",
    'Emissions|CH4': "Mt CH4/yr",
    'Emissions|CO': "Mt CO/yr",
    'Emissions|CO2': 'Mt CO2/yr',
    'Emissions|N2O': 'kt N2O/yr',
    'Emissions|NH3': 'Mt NH3/yr',
    'Emissions|NOx': 'Mt NO2/yr',
    'Emissions|OC': 'Mt OC/yr',
    'Emissions|SF6': 'Mt SF6/yr',
    'Emissions|Sulfur': 'Mt SO2/yr',
    'Emissions|VOC': 'Mt VOC/yr'
}

# %%
for variable in gains_df["variable"].unique():
    gains_df.loc[gains_df["variable"]==variable, "unit"] = unit_map[variable]

# %%
cols = gains_df.columns.tolist()
cols = cols[0:1] + cols[-2:-1] + cols[2:0:-1] + cols[-1:] + cols[3:-2]
cols
# Out:
# ['model',
#  'scenario',
#  'region',
#  'variable',
#  'unit',
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2030,
#  2040,
#  2050,
#  2060,
#  2070,
#  2080,
#  2090,
#  2100]

# %%
gains_df = gains_df[cols]

# %%
gains_df.sort_values(by = ['model', 'scenario', 'variable'], inplace=True)

# %%
gains_df
# Out:
#                      model                     scenario region  \
# 2014  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15|Baseline_CLE  World
# 0     MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15|Baseline_CLE  World
# 2015  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15|Baseline_CLE  World
# 2016  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15|Baseline_CLE  World
# 2017  MESSAGEix-GLOBIOM_GE  SSP2_int_lc_15|Baseline_CLE  World
# ...                    ...                          ...    ...
# 8749  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_tech  World
# 8750  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_tech  World
# 8751  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_tech  World
# 8752  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_tech  World
# 8753  REMIND-Transport 2.1  Transport_NPi_Conv|MFR_tech  World
#
#               variable       unit        1990        1991        1992  \
# 2014      Emissions|BC   Mt BC/yr         NaN         NaN         NaN
# 0        Emissions|CH4  Mt CH4/yr  307.731045  300.207754  296.645175
# 2015      Emissions|CO   Mt CO/yr         NaN         NaN         NaN
# 2016     Emissions|CO2  Mt CO2/yr         NaN         NaN         NaN
# 2017     Emissions|N2O  kt N2O/yr         NaN         NaN         NaN
# ...                ...        ...         ...         ...         ...
# 8749     Emissions|NOx  Mt NO2/yr         NaN         NaN         NaN
# 8750      Emissions|OC   Mt OC/yr         NaN         NaN         NaN
# 8751     Emissions|SF6  Mt SF6/yr         NaN         NaN         NaN
# 8752  Emissions|Sulfur  Mt SO2/yr         NaN         NaN         NaN
# 8753     Emissions|VOC  Mt VOC/yr         NaN         NaN         NaN
#
#             1993        1994  ...        2019          2020          2030  \
# 2014         NaN         NaN  ...         NaN      5.863179      5.362202
# 0     296.988605  296.347795  ...  357.894529    358.927789    384.430987
# 2015         NaN         NaN  ...         NaN     766.54906     696.95561
# 2016         NaN         NaN  ...         NaN  41727.746295  38983.471888
# 2017         NaN         NaN  ...         NaN   9557.825391   10204.84768
# ...          ...         ...  ...         ...           ...           ...
# 8749         NaN         NaN  ...         NaN      104.6219      104.9082
# 8750         NaN         NaN  ...         NaN       28.2977       26.5707
# 8751         NaN         NaN  ...         NaN        5.5085        5.2843
# 8752         NaN         NaN  ...         NaN       75.3632       73.4797
# 8753         NaN         NaN  ...         NaN      127.8951      125.1992
#
#               2040          2050          2060         2070         2080  \
# 2014      4.720507      3.919058      3.225779     2.656437     2.139878
# 0       425.334009    460.999873    484.178829   492.704624   493.081016
# 2015    604.059403    484.524992    388.857895   318.078998   252.947654
# 2016  35823.979785  29656.727666  17594.267719  5568.213731 -1044.763481
# 2017  10345.756187   9848.128349   9429.984531  8900.429089  8040.052627
# ...            ...           ...           ...          ...          ...
# 8749       84.1524       60.4751       62.6345      61.7689      59.7721
# 8750        23.284       20.5612       19.5549      18.7508      18.1054
# 8751        4.9035        4.3332        1.7807       1.7554       1.7196
# 8752       54.6639       35.3752       36.3476      35.2988      32.6977
# 8753      104.3019        83.007       77.9459      73.2909      69.6894
#
#              2090         2100
# 2014     1.734696     1.665407
# 0          477.74   458.001268
# 2015   214.062545   193.998581
# 2016 -7943.961345 -11257.17851
# 2017   7625.44991  7215.610388
# ...           ...          ...
# 8749      56.6964      52.2602
# 8750      17.8862      18.0137
# 8751       1.4903       1.3932
# 8752      28.8056      24.3233
# 8753      67.5286      66.9311
#
# [7458 rows x 44 columns]

# %%
gains_df.to_csv('../data/gains_scenarios_pyam_format.csv', index=False)
